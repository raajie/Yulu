# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Chitra\OneDrive\Documents\ScalerNotes\StatisticalProgramming\CaseStudy\bike_sharing.csv")

# %%
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df.shape
# Out:
# (10886, 12)

# %%
print(f"This Dataset has {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# This Dataset has 10886 rows and 12 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %% [raw]
# We have 4 categorical column, 1 datetime column and 7 continuous column

# %%
df.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %% [raw]
# from the above analysis we can see registered users renting cycles are higher than casual users

# %%
df.isnull().sum(axis = 0)
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %% [raw]
# There are no null values in the dataset

# %% [raw]
# Non-Graphical Analysis:

# %%
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
print("min: ",df['datetime'].min()," max: ", df['datetime'].max())
# Out:
# min:  2011-01-01 00:00:00  max:  2012-12-19 23:00:00

# %%
df["workingday"].value_counts()
# Out:
# workingday
# 1    7412
# 0    3474
# Name: count, dtype: int64

# %%
df["weather"].value_counts()
# Out:
# weather
# 1    7192
# 2    2834
# 3     859
# 4       1
# Name: count, dtype: int64

# %%
df["season"].value_counts()
# Out:
# season
# 4    2734
# 2    2733
# 3    2733
# 1    2686
# Name: count, dtype: int64

# %%
df["holiday"].value_counts()
# Out:
# holiday
# 0    10575
# 1      311
# Name: count, dtype: int64

# %% [raw]
# Insights on Non-Graphical Analysis:
#     --> We have 4 categorical variable and 7 continuous variable
#     --> Registered customers are renting more than casual users
#     --> Renting in all the 4 seasons are almost equal.
#     --> Renting of cycles is more in working day and non-holiday time.

# %% [raw]
# Univariate Analysis:

# %%
sns.countplot(x = df["workingday"])
# Out:
# <Axes: xlabel='workingday', ylabel='count'>

# %%
sns.countplot(x=df["weather"])
# Out:
# <Axes: xlabel='weather', ylabel='count'>

# %%
sns.countplot(x=df["season"])
# Out:
# <Axes: xlabel='season', ylabel='count'>

# %%
sns.countplot(x=df["holiday"])
# Out:
# <Axes: xlabel='holiday', ylabel='count'>

# %%
sns.countplot(x=df["workingday"])
# Out:
# <Axes: xlabel='workingday', ylabel='count'>

# %%
sns.distplot(df["casual"])
# Out:
# C:\Users\Chitra\AppData\Local\Temp\ipykernel_14624\4089019264.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["casual"])
# <Axes: xlabel='casual', ylabel='Density'>

# %%
sns.histplot(df["registered"],kde=True)
# Out:
# <Axes: xlabel='registered', ylabel='Count'>

# %%
sns.histplot(df["humidity"],kde=True)
# Out:
# <Axes: xlabel='humidity', ylabel='Count'>

# %%
sns.histplot(df["temp"],kde=True)
# Out:
# <Axes: xlabel='temp', ylabel='Count'>

# %%
sns.histplot(df["atemp"],kde=True)
# Out:
# <Axes: xlabel='atemp', ylabel='Count'>

# %%
sns.histplot(df["windspeed"],kde=True)
# Out:
# <Axes: xlabel='windspeed', ylabel='Count'>

# %% [raw]
# Insights on Univariate Analysis:
#     --> Weather 1 has highest count whereas weather 4 is having lowest count with record of one day
#     --> All the 4 seasons count are almost in same count.
#     --> Distribution of registered and casual column follows log normal distribution
#     --> Distribution of temp, atemp and humidity column follows normal distribution
#     --> Distribution of windspeed follows binomial distribution

# %% [raw]
# Outlier Detection:

# %%
plt.figure(figsize=(20,15))

plt.subplot(2,2,1)
sns.boxplot(x= df["casual"])

plt.subplot(2,2,2)
sns.boxplot(x= df["registered"])

plt.subplot(2,2,3)
sns.boxplot(x= df["temp"])

plt.subplot(2,2,4)
sns.boxplot(x= df["windspeed"])
# Out:
# <Axes: xlabel='windspeed'>

# %% [raw]
# Analysis on outlier Detection:
#     --> Casual, registered and windspeed have outliers

# %% [raw]
# Bi-Variate Analysis:

# %%
plt.figure(figsize=(20,15))
plt.suptitle("Bi-Variate Analysis for continuous variable")

plt.subplot(3,2,1)
sns.scatterplot(x= df["casual"],y = df["count"])

plt.subplot(3,2,2)
sns.scatterplot(x= df["registered"],y = df["count"])

plt.subplot(3,2,3)
sns.boxplot(x= df["weather"],y = df["count"])

plt.subplot(3,2,4)
sns.scatterplot(x= df["humidity"],y = df["count"])

plt.subplot(3,2,5)
sns.barplot(x= df["temp"],y = df["count"])
plt.xticks(rotation =90,fontsize =10)
plt.show()

# %%
plt.figure(figsize=(20,15))
plt.suptitle("Bi-Variate Analysis for categorical variable")

plt.subplot(2,2,1)


plt.subplot(2,2,2)
sns.boxplot(x= df["workingday"],y = df["count"])

plt.subplot(2,2,3)
sns.boxplot(x= df["season"],y = df["count"])

plt.subplot(2,2,4)
sns.boxplot(x= df["holiday"],y = df["count"])
# Out:
# <Axes: xlabel='holiday', ylabel='count'>

# %% [raw]
# Insights on Bi-Variate Analysis:
#     --> casual and registered variables are positively correlated.
#     --> weather 1 having hightest count and weather 3 has lot of outliers
#     --> Fall season having the highest count of rentals.
#     --> Non-holiday period also having hightest rentals.

# %% [raw]
# Multi-Variate Analysis:

# %%
plt.figure(figsize=(20,15))
plt.suptitle("Multi-Variate Analysis for categorical variable")

plt.subplot(2,2,1)
sns.boxplot(x= df["weather"],y = df["count"],hue =df['season'])

plt.subplot(2,2,2)
sns.boxplot(x= df["workingday"],y = df["count"],hue =df['season'])

plt.subplot(2,2,3)
sns.boxplot(x= df["holiday"],y = df["count"],hue =df['season'])

plt.subplot(2,2,4)
sns.boxplot(x= df["humidity"],y = df["count"],hue =df['season'])
# Out:
# <Axes: xlabel='holiday', ylabel='count'>

# %% [raw]
# Insights on Multi-Variate Analysis:
#     --> Rental is higher in all the other seasons than season 1.
#     --> Most of the rentals has registered in season Fall.
#     --> Weather 1, working day and non-holiday period is having the highest rentals.

# %%
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df["workingday"].value_counts()
# Out:
# workingday
# 1    7412
# 0    3474
# Name: count, dtype: int64

# %% [raw]
# Hypothesis Testing

# %% [raw]
# 2 - Sample T-Test:

# %% [raw]
# H0: Working days has no effect on no.of.cycles rented
# H1: Working days has effect on no.of.cycles rented

# %%
from scipy.stats import norm,ttest_1samp,ttest_ind,ttest_rel,f_oneway
from scipy.stats import levene,shapiro,kruskal

# %%
s1 = df[df["workingday"]==1]["count"]

# %%
s2 = df[df["workingday"]==0]["count"]

# %%
ttest_ind(s1,s2,alternative = "two-sided")
# Out:
# TtestResult(statistic=1.2096277376026694, pvalue=0.22644804226361348, df=10884.0)

# %% [raw]
# alpha:0.05
# We accept null hypothesis as p-value is high
# Working day has effect on no.of.cycles rented

# %%
ANNOVA:

# %% [raw]
# H0: No.of.Cycles rented in different weather is same
# H1: No.of.Cycles rented in different weather is different

# %%
w1 = df[df["weather"]==1]["count"]
w2 = df[df["weather"]==2]["count"]
w3 = df[df["weather"]==3]["count"]
w4 = df[df["weather"]==4]["count"]

# %%
df[df["weather"]==1]['count'].mean()
# Out:
# 205.23679087875416

# %%
sns.boxplot(x =df["weather"], y= df["count"])
# Out:
# <Axes: xlabel='weather', ylabel='count'>

# %%
from statsmodels.graphics.gofplots import qqplot

# %% [raw]
# H0: Variance within each group is same
# H1: Variance is different across group
#
# H0: Data is normally distributed
# H1: Data is not normally distributed

# %%
qqplot(df['count'],line='s')
plt.show()

# %%
shapiro(df['count'].sample(100))
# Out:
# ShapiroResult(statistic=0.8732032775878906, pvalue=9.460635652658311e-08)

# %% [raw]
# alpha: 0.05
# P-Value is low, hence we reject null hypothesis
# Data is not normally distributed

# %%
levene(w1,w2,w3,w4)
# Out:
# LeveneResult(statistic=54.85106195954556, pvalue=3.504937946833238e-35)

# %%
sns.displot(data = df, x = 'count',hue = 'weather',kind='kde')
# Out:
# C:\Users\Chitra\AppData\Local\Temp\ipykernel_14624\1424922016.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.displot(data = df, x = 'count',hue = 'weather',kind='kde')
# C:\Users\Chitra\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [raw]
# alpha: 0.05
# P-Value is low, hence we reject null hypothesis
# Variance is different across each group

# %% [raw]
# Assumptions of ANNOVA is not satisfied hence we do kruskal wallis test

# %%
kruskal(w1,w2,w3,w4)
# Out:
# KruskalResult(statistic=205.00216514479087, pvalue=3.501611300708679e-44)

# %% [raw]
# alpha: 0.05
# p-Value is low, hence we reject null hypothesis
# No.of.Cycles rented in different weather are not same

# %% [raw]
# ANNOVA:(for season)

# %% [raw]
# H0: No.of.Cycles rented in different season is same
# H1: No.of.Cycles rented in different season is different

# %%
df['season'].value_counts()
# Out:
# season
# 4    2734
# 2    2733
# 3    2733
# 1    2686
# Name: count, dtype: int64

# %%
s1 = df[df['season']==1]['count']
s2 = df[df['season']==2]['count']
s3 = df[df['season']==3]['count']
s4 = df[df['season']==4]['count']

# %% [raw]
# H0:Variance is same across different season
# H1: Variance is different across different season

# %%
sns.boxplot(x=df['season'],y = df['count'])
# Out:
# <Axes: xlabel='season', ylabel='count'>

# %%
sns.displot(data = df,x = 'count',hue = 'season',kind = 'kde')
# Out:
# C:\Users\Chitra\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
levene(s1,s2,s3,s4)
# Out:
# LeveneResult(statistic=187.7706624026276, pvalue=1.0147116860043298e-118)

# %% [raw]
# alpha: 0.05
# p-value is low, hence we reject null hypothesis
# variance is not same across different seasons

# %% [raw]
# Assumptions of ANNOVA is not satisfied hence we do kruskal wallis test

# %%
kruskal(s1,s2,s3,s4)
# Out:
# KruskalResult(statistic=699.6668548181988, pvalue=2.479008372608633e-151)

# %% [raw]
# alpha: 0.05
# p-value is low, hence we reject null hypothesis
# No.of.cycles rented in different seasons is not same

# %% [raw]
# Chi-Square Test

# %% [raw]
# H0:Weather is independent of seasons
# H1: Weather is dependent on seasons

# %%
from scipy.stats import chi2_contingency

# %%
ct = pd.crosstab(df['season'],df['weather'])

# %%
ct
# Out:
# weather     1    2    3  4
# season
# 1        1759  715  211  1
# 2        1801  708  224  0
# 3        1930  604  199  0
# 4        1702  807  225  0

# %%
observed = [[1759,715,211,1],[1801,708,224,0],[1930,604,199,0],[1702,807,225,0]]

# %%
t_stats, p_value, dof, exp_val = chi2_contingency(observed)

# %%
print("t_statistics: ",t_stats, "p_value: ",p_value)
# Out:
# t_statistics:  49.158655596893624 p_value:  1.549925073686492e-07

# %% [raw]
# alpha: 0.05
# we reject null hypothesis as p_value is low
# Weather is dependent on seasons

# %% [raw]
# Recommendations:
#     --> Company can focus on acquiring more registered customer by providing offers. We can see registered customers are regular and having high count in rental.
#     --> Working day, non-holiday period seems to have high demand of rentals, so company can focus on availability of cycles on those days.
